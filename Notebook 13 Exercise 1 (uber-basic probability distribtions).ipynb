# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#creating first plot - just a uniform distribution
rand = np.random.rand(1000)
plt.hist(rand)
# Out:
# (array([ 96.,  97., 108., 107., 101.,  92.,  98.,  97., 103., 101.]),
#  array([6.51840666e-04, 1.00533883e-01, 2.00415924e-01, 3.00297966e-01,
#         4.00180008e-01, 5.00062050e-01, 5.99944092e-01, 6.99826134e-01,
#         7.99708176e-01, 8.99590218e-01, 9.99472260e-01]),
#  <BarContainer object of 10 artists>)

# %%
#similar to before, but we can shift the range with + and *
big_rand = 5 + 10*np.random.rand(1000)
plt.hist(big_rand)
# Out:
# (array([107.,  98.,  89.,  95., 114.,  84., 102., 116., 105.,  90.]),
#  array([ 5.04710165,  6.04211921,  7.03713677,  8.03215433,  9.02717189,
#         10.02218945, 11.01720701, 12.01222457, 13.00724213, 14.0022597 ,
#         14.99727726]),
#  <BarContainer object of 10 artists>)
